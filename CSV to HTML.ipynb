# %%
import pandas as pd

# %%
df = pd.read_csv('cities_3.0.csv')
df.head()
# Out:
#    Unnamed: 0          City  Cloudiness Country  Humidity        Date    Lat  \
# 0           0    phalaborwa        52.0      ZA      94.0  1576111102 -23.95
# 1           1      uyemskiy        75.0      RU      73.0  1576111209  64.47
# 2           2  puerto ayora        20.0      EC      65.0  1576111209  -0.74
# 3           3         vaini         2.0      IN      93.0  1576111209  15.34
# 4           4   tuktoyaktuk         5.0      CA      69.0  1576111210  69.44
#
#       Lng  Max Temp  Windspeed
# 0   31.14      22.0       1.50
# 1   40.85      -3.0       4.00
# 2  -90.35      25.0       7.70
# 3   74.49      16.0       1.26
# 4 -133.03     -25.0       7.70

# %%
html_table = df.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Unnamed: 0</th>\n      <th>City</th>\n      <th>Cloudiness</th>\n      <th>Country</th>\n      <th>Humidity</th>\n      <th>Date</th>\n      <th>Lat</th>\n      <th>Lng</th>\n      <th>Max Temp</th>\n      <th>Windspeed</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>phalaborwa</td>\n      <td>52.0</td>\n      <td>ZA</td>\n      <td>94.0</td>\n      <td>1576111102</td>\n      <td>-23.95</td>\n      <td>31.14</td>\n      <td>22.00</td>\n      <td>1.50</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>1</td>\n      <td>uyemskiy</td>\n      <td>75.0</td>\n      <td>RU</td>\n      <td>73.0</td>\n      <td>1576111209</td>\n      <td>64.47</td>\n      <td>40.85</td>\n      <td>-3.00</td>\n      <td>4.00</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2</td>\n      <td>puerto ayora</td>\n      <td>20.0</td>\n      <td>E
# ...

# %%
df.to_html('table.html')
